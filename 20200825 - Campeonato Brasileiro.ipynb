# %% [markdown]
# #CAMPEONATO BRASILEIRO

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/My Drive/MY ANALYSIS/20200825 - Campeonato Brasileiro/Dataset/novo_campeonato_brasileiro.csv')
df.head()
# Out:
#              ID        Data   Ano  ...  Vencedor             Arena  OBS
# 0  2003.01.0001  29/03/2003  2003  ...  Mandante    Brinco de Ouro  NaN
# 1  2003.01.0002  29/03/2003  2003  ...  Mandante  Arena da Baixada  NaN
# 2  2003.01.0003  30/03/2003  2003  ...    Empate          Maracanã  NaN
# 3  2003.01.0004  30/03/2003  2003  ...    Empate     Serra Dourada  NaN
# 4  2003.01.0005  30/03/2003  2003  ...    Empate         Beira-Rio  NaN
#
# [5 rows x 13 columns]

# %%
df2016 = df.loc[df.Ano==2016]
df2016
# Out:
#                 ID        Data   Ano  ...   Vencedor                Arena  OBS
# 5366  2016.01.0001  14/05/2016  2016  ...   Mandante  Raulino de Oliveira  NaN
# 5367  2016.01.0002  14/05/2016  2016  ...   Mandante      Palestra Itália  NaN
# 5368  2016.01.0003  14/05/2016  2016  ...   Mandante        Independência  NaN
# 5369  2016.01.0004  14/05/2016  2016  ...   Mandante        Couto Pereira  NaN
# 5370  2016.01.0005  15/05/2016  2016  ...   Mandante               Arruda  NaN
# ...            ...         ...   ...  ...        ...                  ...  ...
# 5741  2016.38.0376  11/12/2016  2016  ...   Mandante     Moisés Lucarelli  NaN
# 5742  2016.38.0377  11/12/2016  2016  ...   Mandante         Vila Belmiro  NaN
# 5743  2016.38.0378  11/12/2016  2016  ...   Mandante             Pacaembu  NaN
# 5744  2016.38.0379  11/12/2016  2016  ...   Mandante       Ilha do Retiro  NaN
# 5745  2016.38.0380  11/12/2016  2016  ...  Visitante             Barradão  NaN
#
# [380 rows x 13 columns]

# %%
pontosMandante=[]
for i in df.Vencedor:
  if df2016.Vencedor == 'Mandante':
    pontosMandante = pontosMandante.append(3)
  elif df2016.Vencedor == 'Visitante':
    pontosMandante = pontosMandante.append(0)
  else:
    pontosMandante = pontosMandante.append(1)

df2016['Pontos_mandante'] = pontosMandante
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-b5860c0f8ce5> in <module>()
#       1 pontosMandante=[]
#       2 for i in df.Vencedor:
# ----> 3   if df2016.Vencedor == 'Mandante':
#       4     pontosMandante = pontosMandante.append(3)
#       5   elif df2016.Vencedor == 'Visitante':
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1477     def __nonzero__(self):
#    1478         raise ValueError(
# -> 1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1481         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
